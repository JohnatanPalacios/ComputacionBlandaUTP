# %%
import pandas as pd

# %% [markdown]
# # **Series**
# > Es un vector unidimensional con un índice, para poder acceder a esta lista podemos usar posiciones o labels, siendo este último el preferido para manipular las series. Una diferencia importante sobre las listas de Python es que los datos son homogéneos, es decir solo podemos tener un tipo de dato por cada Serie.
#
# > Se pueden crear a partir de cualquier secuencia(listas, tuplas, arrays de numpy y diccionarios).
# >> Ej. series = pd.Series([1,2,3])
#
# > En Python tenemos la filosofía del Duck Typing, si se ve como un pato y hace cuac, a ese animal le llamamos pato, si una serie se comporta una lista, se accede como una lista en principio deberíamos llamarla lista, pero esto no es así.
# Una mejor aproximación para inicializar Series es utilizar diccionarios.
# >> Ej. series = pd.Series({'a': 1, 'b': 2, 'c': 3})

# %%
series_test = pd.Series([100, 200, 300])
series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48,
                          2000: 65,
                          2001: 89})
series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# # **DataFrames**
#
# > - Es una tabla con filas y columnas etiquetadas
# > - Se pueden construír con arrays bidimensionales de numpy, listas de listas, listas de tuplas, un diccionario de Python u otro DataFrame
# >> - Al igual que en las Series, cuando utilizamos un diccionario, sus llaves se convierten en el índice de las columnas
# >> - Cuando utilizamos una lista, podemos utilizar el parámetros opcinal columns
#
# Ojo!! Si solo se tiene una dimensión, se le llama Serie y no DataFrame

# %%
frame_test = pd.DataFrame({1999: [54, 56, 67],
                           2000: [23, 45, 88],
                           2001: [234, 23, 87]})
frame_test
# Out:
#    1999  2000  2001
# 0    54    23   234
# 1    56    45    23
# 2    67    88    87

# %%
# Cuando se tiene una lista de listas, no se puede definir el índice
# por eso se usa el columns, donde se agregan los labels

frame_test2 = pd.DataFrame([[54, 56, 67],
                           [23, 45, 88],
                           [234, 23, 87]], columns=[1999, 2000, 2001])
frame_test2
# Out:
#    1999  2000  2001
# 0    54    56    67
# 1    23    45    88
# 2   234    23    87

# %% [markdown]
# # **Índices y selección**
#
# - Existen muchas formas de acceder a los datos
#  - Ditionary like, Ej:
#   > - df['col1'] # Retorna un DataSeries
#   > - dk[['col1', 'col3']] # Retorna un DataFrame
#
#  - Numpy like, ej:
#  > - df.iloc[:] # fila
#  > - df.iloc[:, :] # fila, columna
#
#  - Label based, ej:
#  > - df.loc[:] # fila
#  > - df.loc[:, :] # fila, columna

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
el_universal = pd.read_csv('/content/drive/MyDrive/Platzi/wep scrapper curso data engeneering/eluniversal_2019_06_07_articles.csv')

type(el_universal)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.options.display.max_rows = 10
# el_universal.head() # muestra los primeros 5 datos
# el_universal.tail() # muestra los ultimoss 5 datos
el_universal
# Out:
#                                                   body  ...                                                url
# 0    \nLa procuradora Ernestina Godoy confirmó que ...  ...  http://www.eluniversal.com.mx/metropoli/cdmx/m...
# 1                                                  NaN  ...         http://www.eluniversal.com.mx/deportes/box
# 2                                                  NaN  ...  https://www.tangible-eluniversal.com.mx/en-ver...
# 3    \n\nTras el triunfo de Barbosa y la derrota de...  ...  https://www.eluniversal.com.mx/articulo/maria-...
# 4    \n\nLa noticia de que las niñas y niños de la ...  ...  https://www.eluniversal.com.mx/articulo/letici...
# ..                                                 ...  ...                                                ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...  ...  http://www.eluniversal.com.mx/metropoli/cdmx/p...
# ...

# %% [markdown]
# #**Index and selection**

# %%
# dictionary like: acceso de estilo diccionario

el_universal['title']
# Out:
# 0      Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                    NaN
# 2                                                    NaN
# 3      Puebla: un tropiezo electoral no es una derrot...
# 4                              Entre faldas y pantalones
#                              ...
# 194    Policía auxilia a hombre de la tercera edad qu...
# 195    Las primeras reporteras que rompieron con los ...
# 196    Grupo armado ataca a subdirector de Seguridad ...
# 197                                                  NaN
# 198           Concacaf pide al Tri priorizar la Copa Oro
# Name: title, Length: 199, dtype: object

# %%
el_universal[['title', 'url']]
# Out:
#                                                  title                                                url
# 0    Matan a exdiputado de Tláhuac; investigan vínc...  http://www.eluniversal.com.mx/metropoli/cdmx/m...
# 1                                                  NaN         http://www.eluniversal.com.mx/deportes/box
# 2                                                  NaN  https://www.tangible-eluniversal.com.mx/en-ver...
# 3    Puebla: un tropiezo electoral no es una derrot...  https://www.eluniversal.com.mx/articulo/maria-...
# 4                            Entre faldas y pantalones  https://www.eluniversal.com.mx/articulo/letici...
# ..                                                 ...                                                ...
# 194  Policía auxilia a hombre de la tercera edad qu...  http://www.eluniversal.com.mx/metropoli/cdmx/p...
# 195  Las primeras reporteras que rompieron con los ...  https://www.eluniversal.com.mx/mochilazo-en-el...
# ...

# %%
# Numpy like: acceso por posiciones

el_universal.iloc[10:15] # fila 10 a la 15
# Out:
#                                                  body  ...                                                url
# 10                                                NaN  ...                             https://bit.ly/2jmdiXT
# 11                                                NaN  ...  http://www.eluniversal.com.mx/autor-opinion/ar...
# 12  El año 2019 todavía es joven, pero un par de m...  ...  https://www.elgrafico.mx/espectaculos/ellas-so...
# 13                                                NaN  ...  http://www.eluniversal.com.mx/autor-opinion/ar...
# 14  La banda de rock Los Amigos Invisibles se pres...  ...  http://www.unionedomex.mx/articulo/2019/06/07/...
#
# [5 rows x 3 columns]

# %%
el_universal.iloc[66]['title']
# Out:
# 'Naasón “ha sido víctima de complot cibernético”, dice defensa'

# %%
el_universal.iloc[:5, 0] # de la fila 0 a la 5 y muestra la columna 0, no es recomendada, no es legible
# Out:
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# Name: body, dtype: object

# %%
# acceder con labels, forma recomendada

el_universal.loc[:, 'body': 'title'] # trae todos los registros, pero solo body y title
# Out:
#                                                   body                                              title
# 0    \nLa procuradora Ernestina Godoy confirmó que ...  Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN                                                NaN
# 2                                                  NaN                                                NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...  Puebla: un tropiezo electoral no es una derrot...
# 4    \n\nLa noticia de que las niñas y niños de la ...                          Entre faldas y pantalones
# ..                                                 ...                                                ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...  Policía auxilia a hombre de la tercera edad qu...
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...  Las primeras reporteras que rompieron con los ...
# ...

# %% [markdown]
# #**Data Wrangling**
# Domado de datos
#
# > Esta es una de las actividades más importantes para todos los profesionales de los datos. Consiste en limpiar, transformar y entiquecer el dataset para objetivos posteriores, ej:
#  - Inserción en una base de datos
#  - Visualización
#
# > Pandas es una de las herramientas más poderosas para realizar este ejercicio, nos permite:
#  - Generar transformaciones con gran facilidad
#  - Trabajar rápidamente con datasets grandes
#  - Detectar y reemplazar datos faltantes
#  - Agrupar y resumir nuestros datos
#  - Visualizar nuestros resultados

# %%
# 1. Añadir el newspaper_uid al DataFrame

el_universal['newspaper_uid'] = 'eluniversal'
el_universal
# Out:
#                                                   body  ... newspaper_uid
# 0    \nLa procuradora Ernestina Godoy confirmó que ...  ...   eluniversal
# 1                                                  NaN  ...   eluniversal
# 2                                                  NaN  ...   eluniversal
# 3    \n\nTras el triunfo de Barbosa y la derrota de...  ...   eluniversal
# 4    \n\nLa noticia de que las niñas y niños de la ...  ...   eluniversal
# ..                                                 ...  ...           ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...  ...   eluniversal
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...  ...   eluniversal
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...  ...   eluniversal
# 197                                                NaN  ...   eluniversal
# 198                                                NaN  ...   eluniversal
#
# [199 rows x 4 columns]

# %%
# 2. Obtener el host

from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                   body  ...                             host
# 0    \nLa procuradora Ernestina Godoy confirmó que ...  ...           www.eluniversal.com.mx
# 1                                                  NaN  ...           www.eluniversal.com.mx
# 2                                                  NaN  ...  www.tangible-eluniversal.com.mx
# 3    \n\nTras el triunfo de Barbosa y la derrota de...  ...           www.eluniversal.com.mx
# 4    \n\nLa noticia de que las niñas y niños de la ...  ...           www.eluniversal.com.mx
# ..                                                 ...  ...                              ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...  ...           www.eluniversal.com.mx
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...  ...           www.eluniversal.com.mx
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...  ...           www.eluniversal.com.mx
# ...

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx             115
# www.elbotiquin.mx                    9
# www.viveusa.mx                       9
# bit.ly                               8
# www.tangible-eluniversal.com.mx      7
#                                   ...
# www.unionedomex.mx                   1
# www.facebook.com                     1
# www.unionguanajuato.mx               1
# twitter.com                          1
# www.unionyucatan.mx                  1
# Name: host, Length: 22, dtype: int64

# %% [markdown]
# #**Datos faltantes**
# ###Missing data
#
# - Los datos faltantes son un hecho de la vida
# - Pandas nos otorga distintas estrategias (todas con diferentes 'tradeoffs') para solucionar este problema
#  - Eliminar el registro (fila o columna)
#   >- .isna()
#    - .notna()
#    - .dropna()
#  - Reemplazar el registro
#   >- .fillna() # utiliza un valor sentinela
#    - .ffill() # utiliza último valor utilizado

# %%
# 3. Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()

missing_titles = (el_universal[missing_titles_mask]['url']
                  .str.extract(r'(?P<missing_titles>[^/]+)$')
                  .applymap(lambda title: str(title).split('-'))
                  .applymap(lambda title_word_list: ' '.join(title_word_list))
                  .applymap(lambda final_title: final_title.capitalize())
                  )
"""
missing_titles = (el_universal[missing_titles_mask]['url']
                  .str.extract(r'(?P<missing_titles>[^/]+)$')
                  .applymap(lambda title: str(title).replace('-', ' ').capitalize()))
"""
el_universal.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']
missing_titles
# Out:
#                                         missing_titles
# 1                                                  Box
# 2    En verdad padecio sifilis schubert el gran com...
# 6    Ladron se dispara durante asalto pizzeria en m...
# 9    Las bacterias que viven en tu celular y otros ...
# 10                                             2jmdixt
# ..                                                 ...
# 182  10 famosos que lucen irreconocibles con unos k...
# 188                                      Suscripciones
# 191                                            1twqkcr
# 192             6 ejercicios para tonificar los brazos
# 197                                          Seguridad
#
# [65 rows x 1 columns]

# %% [markdown]
# #**Additional cleanup**

# %%
# 4. añadir uid a las filas

import hashlib

# axis: el eje 1 son las filas y el eje 0 columnas
uids = (el_universal
        .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
        .apply(lambda hash_object: hash_object.hexdigest())
)

el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True)
el_universal
# Out:
#                                                                                body  ...                             host
# uid                                                                                  ...
# 6c7bf68194a8a5998597239b29be7e41  \nLa procuradora Ernestina Godoy confirmó que ...  ...           www.eluniversal.com.mx
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN  ...           www.eluniversal.com.mx
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN  ...  www.tangible-eluniversal.com.mx
# 35e6ddcb6722ef46c2f60a04d4e33229  \n\nTras el triunfo de Barbosa y la derrota de...  ...           www.eluniversal.com.mx
# 217d524b953cf2f3dabfe160622cc128  \n\nLa noticia de que las niñas y niños de la ...  ...           www.eluniversal.com.mx
# ...                                                                             ...  ...                              ...
# ...

# %%
# al optener el hash se procede a eliminar el salto de línea \n

stripped_body = (el_universal
                 .apply(lambda row: row['body'], axis=1)
                 .apply(lambda body: list(str(body)))
                 .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''), letters)))
                 .apply(lambda letters: ''.join(letters))
                 )
stripped_body
# Out:
# uid
# 6c7bf68194a8a5998597239b29be7e41    La procuradora Ernestina Godoy confirmó que el...
# cb18691c58018e4163d72b0ed8bbcf38                                                  nan
# cf5bc6c8b4056dc4120a47d67699919e                                                  nan
# 35e6ddcb6722ef46c2f60a04d4e33229    Tras el triunfo de Barbosa y la derrota de Cár...
# 217d524b953cf2f3dabfe160622cc128    La noticia de que las niñas y niños de la Ciud...
#                                                           ...
# 3486e1b91f94db6ad09d8d3dbef782e2    CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22    Texto: Aída Castro SánchezDiseño web: Miguel Á...
# fef05cb73c5ba11f41aa58190726ca5a    Tingüindín, Michoacán.- Diego Vidal Manzo, sub...
# ab3f9d29135096228449397395057c36                                                  nan
# dcdefeba6e4c6905af58a3b68f8bee94                                                  nan
# Length: 199, dtype: object

# %%
# hacer lo mismo de arriba, pero más simple y rápido
"""
stripped_body2 = (el_universal
                    .apply(lambda row: row['body'], axis=1)
                    .apply(lambda body: str(body).replace('\n',''))
                    .apply(lambda body: body.replace('\r',''))
                )

stripped_body2
"""
# Out:
# "\nstripped_body2 = (el_universal\n                    .apply(lambda row: row['body'], axis=1)\n                    .apply(lambda body: str(body).replace('\n',''))\n                    .apply(lambda body: body.replace('\r',''))\n                )\n\nstripped_body2\n"

# %%
# otra forma de limpiar
"""
import re

stripped_body3 = (el_universal
                    .apply(lambda row: row['body'], axis=1)
                    .apply(lambda body: re.sub(r'(\n|\r)+',r'', str(body)))
                )

stripped_body3
"""
# Out:
# "\nimport re\n\nstripped_body3 = (el_universal\n                    .apply(lambda row: row['body'], axis=1)\n                    .apply(lambda body: re.sub(r'(\n|\r)+',r'', str(body)))\n                )\n\nstripped_body3\n"

# %%
# otra forma más simple
# el_universal.apply(lambda row: str(row['body']).replace('\n', ''), axis=1)

# %% [markdown]
# #**Data enrichment**

# %%
# 6. tokenizar el titulo y el body
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
  return (df
          .dropna()
          .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
          .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
          .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
          .apply(lambda words_list: list(filter(lambda word: word not in stop_words, words_list)))
          .apply(lambda valid_word_list: len(valid_word_list))
          )

el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')
el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body')
el_universal
# Out:
#                                                                                body  ... n_tokens_body
# uid                                                                                  ...
# 6c7bf68194a8a5998597239b29be7e41  \nLa procuradora Ernestina Godoy confirmó que ...  ...          65.0
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN  ...           NaN
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN  ...           NaN
# 35e6ddcb6722ef46c2f60a04d4e33229  \n\nTras el triunfo de Barbosa y la derrota de...  ...         305.0
# 217d524b953cf2f3dabfe160622cc128  \n\nLa noticia de que las niñas y niños de la ...  ...         322.0
# ...                                                                             ...  ...           ...
# 3486e1b91f94db6ad09d8d3dbef782e2  \nCDMX.- Cerca de las 18:30 horas, un hombre d...  ...          46.0
# ...

# %% [markdown]
# #**Duplicate values**

# %%
# 8. Eliminar duplicados

el_universal['title'].value_counts()
# Out:
# Mitin “por la dignidad” se convierte en celebración                                2
# Trump frena aranceles con pacto migratorio                                         2
# Ámsterdam ofrece casarte por un día con un holandés para explorar la ciudad        2
# Concacaf pide al Tri priorizar la Copa Oro                                         2
# Cinco siglos del idioma español en México                                          2
#                                                                                   ..
# Policía auxilia a hombre de la tercera edad que cayó a las vías en Metro Juárez    1
# Tras lluvia, reportan derrumbe en la Álvaro Obregón                                1
# Farandula                                                                          1
# No habrá aranceles a exportaciones, sí reducción a migración                       1
# Ricardo Homs                                                                       1
# Name: title, Length: 192, dtype: int64

# %%
# se le pasa una máscara booleana para analizar la información

el_universal[el_universal['title'] == 'Mitin “por la dignidad” se convierte en celebración']
# Out:
#                                                                                body  ... n_tokens_body
# uid                                                                                  ...
# d1c306d3311e161ac3d49a83fcf11267                                                NaN  ...           NaN
# f8ade06569bbf1199fae9a567bea3397  \n[email protected]\n\nTijuana, BC.— El presid...  ...         319.0
#
# [2 rows x 7 columns]

# %%
el_universal.drop_duplicates(subset=['title'], keep='first', inplace=True)

# %% [markdown]
# ##**Final table**

# %%
# Tabla final

el_universal
# Out:
#                                                                                body  ... n_tokens_body
# uid                                                                                  ...
# 6c7bf68194a8a5998597239b29be7e41  \nLa procuradora Ernestina Godoy confirmó que ...  ...          65.0
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN  ...           NaN
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN  ...           NaN
# 35e6ddcb6722ef46c2f60a04d4e33229  \n\nTras el triunfo de Barbosa y la derrota de...  ...         305.0
# 217d524b953cf2f3dabfe160622cc128  \n\nLa noticia de que las niñas y niños de la ...  ...         322.0
# ...                                                                             ...  ...           ...
# fefe2a7902716da5e068e6a55171d7a0  \nFelipe Orocuta, boxeador mexicano, está sien...  ...          64.0
# ...

# %% [markdown]
# #**Descriptive analysis**

# %%
clean_eluniversal = pd.read_csv('/content/drive/MyDrive/Platzi/wep scrapper curso data engeneering/clean_eluniversal_2019_06_07_articles.csv')
clean_elpais = pd.read_csv('/content/drive/MyDrive/Platzi/wep scrapper curso data engeneering/clean_elpais_2020_07_21_articles.csv')

# %%
clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count      192.000000     192.000000
# mean         4.697917     200.197917
# std          2.320497     265.138159
# min          0.000000       1.000000
# 25%          4.000000       1.000000
# 50%          5.000000     136.500000
# 75%          6.000000     260.250000
# max         10.000000    2105.000000

# %%
clean_elpais.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       62.000000      62.000000
# mean         5.387097     476.338710
# std          2.397778     354.762259
# min          0.000000      52.000000
# 25%          3.000000     294.000000
# 50%          5.500000     421.000000
# 75%          7.000000     611.250000
# max         10.000000    1783.000000

# %%
clean_eluniversal.loc[clean_eluniversal['n_tokens_title'] == 0]
# Out:
#                                   uid body  ... n_tokens_title n_tokens_body
# 10   1b5e6bc6261b96616dc9e98f51bcd8b1  NaN  ...              0             1
# 21   4479389b7e7fb735bd0fa2f0197e5580  NaN  ...              0             1
# 28   53471adb0b7b3cd451eb682d24226b13  NaN  ...              0             1
# 40   b31fa322be921f08482c44530571e644  NaN  ...              0             1
# 44   45bd435035270d052cbb70b70d9d1980  NaN  ...              0             1
# ..                                ...  ...  ...            ...           ...
# 76   5da5c245ef720979b25c36ac56a7cce3  NaN  ...              0             1
# 86   65a79b03bc8bc6d950397790da8cccc1  NaN  ...              0             1
# 147  08c93717e232ae8cbd50024cff47a0cd  NaN  ...              0             1
# 171  4a50e79f46d0e070905ac3d5506ab29f  NaN  ...              0             1
# 185  481ff64955ad725df74ae0cc6913bd57  NaN  ...              0             1
#
# [15 rows x 8 columns]

# %%
# %matplotlib inline

# %%
clean_eluniversal['n_tokens_title'].plot(style='k.')
clean_elpais['n_tokens_title'].plot(style='r.')

# %%
clean_eluniversal['n_tokens_body'].plot(style='k.')
clean_elpais['n_tokens_body'].plot(style='r.')

# %%
all_newspapers = pd.concat([clean_eluniversal, clean_elpais])

grouped = all_newspapers.groupby('newspaper_uid')

grouped.hist()
# Out:
# newspaper_uid
# elpais         [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min', 'mean', 'max'])
# Out:
#                min        mean   max
# newspaper_uid
# elpais          52  476.338710  1783
# eluniversal      1  200.197917  2105

# %%
grouped.plot()
# Out:
# newspaper_uid
# elpais         AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
